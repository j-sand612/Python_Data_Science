# %% [markdown]
# # Importing Datasets

# %%
import pandas as pd
csvLoc = "C:\\Users\\sando\\Downloads\\villagers.csv"
villagerDf = pd.read_csv(csvLoc)
villagerDf.head(10)
# Out:
# C:\Users\sando\Downloads\villagers.csv
#    row_n        id      name  gender    species birthday personality  \
# 0      2   admiral   Admiral    male       bird     1-27      cranky
# 1      3   agent-s   Agent S  female   squirrel      7-2       peppy
# 2      4     agnes     Agnes  female        pig     4-21        uchi
# 3      6        al        Al    male    gorilla    10-18        lazy
# 4      7   alfonso   Alfonso    male  alligator      6-9        lazy
# 5      8     alice     Alice  female      koala     8-19      normal
# 6      9      alli      Alli  female  alligator     11-8      snooty
# 7     10    amelia    Amelia  female      eagle    11-19      snooty
# 8     11  anabelle  Anabelle  female   anteater     2-16       peppy
# 9     13   anchovy   Anchovy    male       bird      3-4        lazy
#
#            song    phrase            full_id  \
# 0    Steep Hill   aye aye   villager-admiral
# 1       DJ K.K.  sidekick   villager-agent-s
# ...

# %%
villagerDf.tail(10)
# Out:
#      row_n        id      name  gender  species birthday personality  \
# 381    470   wart-jr  Wart Jr.    male     frog     8-21      cranky
# 382    471     weber     Weber    male     duck     6-30        lazy
# 383    472     wendy     Wendy  female    sheep     8-15       peppy
# 384    473   whitney   Whitney  female     wolf     9-17      snooty
# 385    474    willow    Willow  female    sheep    11-26      snooty
# 386    475    winnie    Winnie  female    horse     1-31       peppy
# 387    477  wolfgang  Wolfgang    male     wolf    11-25      cranky
# 388    480      yuka      Yuka  female    koala     7-20      snooty
# 389    481      zell      Zell    male     deer      6-7        smug
# 390    483    zucker    Zucker    male  octopus      3-8        lazy
#
#                 song      phrase            full_id  \
# 381      To the Edge  grr-ribbit   villager-wart-jr
# 382      K.K. Fusion        quaa     villager-weber
# ...

# %%
itemLoc = "C:\\Users\\sando\\Downloads\\items.csv"
itemDf = pd.read_csv(itemLoc)
itemDf.head(10)
# Out:
#    num_id                    id                  name     category orderable  \
# 0      12            3d-glasses            3D Glasses  Accessories       NaN
# 1      14                 a-tee                 A Tee         Tops       NaN
# 2      17         abstract-wall         Abstract Wall    Wallpaper      True
# 3      19       academy-uniform       Academy Uniform      Dresses       NaN
# 4      20          acanthostega          Acanthostega      Fossils     False
# 5      21     accessories-stand     Accessories Stand    Furniture      True
# 6      23    acid-washed-jacket    Acid-washed Jacket         Tops      True
# 7      24     acid-washed-jeans     Acid-washed Jeans      Bottoms      True
# 8      26  acnh-nintendo-switch  Acnh Nintendo Switch    Furniture      True
# 9      26  acnh-nintendo-switch  Acnh Nintendo Switch    Furniture      True
#
#    sell_value sell_currency  buy_value buy_currency  \
# 0       122.0         bells      490.0        bells
# ...

# %%
savePath = "C:\\Users\\sando\\Documents\\Python_Data_Science\\Datasets\\items.csv"
villagerSavePath = "C:\\Users\\sando\\Documents\\Python_Data_Science\\Datasets\\villagers.csv"
itemDf.to_csv(savePath)
villagerDf.to_csv(villagerSavePath)

# %% [markdown]
# # Show Datafram datatypes

# %%
villagerDf.dtypes
# Out:
# row_n           int64
# id             object
# name           object
# gender         object
# species        object
# birthday       object
# personality    object
# song           object
# phrase         object
# full_id        object
# url            object
# dtype: object

# %%
itemDf.dtypes
# Out:
# num_id             int64
# id                object
# name              object
# category          object
# orderable         object
# sell_value       float64
# sell_currency     object
# buy_value        float64
# buy_currency      object
# sources           object
# customizable      object
# recipe           float64
# recipe_id         object
# games_id          object
# id_full           object
# image_url         object
# dtype: object

# %% [markdown]
# # Statistical Analysis

# %%
villagerDf.describe()
#row_n is just the row index
# Out:
#             row_n
# count  391.000000
# mean   239.902813
# std    140.702672
# min      2.000000
# 25%    117.500000
# 50%    240.000000
# 75%    363.500000
# max    483.000000

# %%
itemDf.describe()
# Out:
#             num_id     sell_value     buy_value      recipe
# count  4565.000000    4529.000000  3.551000e+03  588.000000
# mean   3661.618839    2261.378229  6.959650e+03    4.710884
# std    2187.950090   11313.225932  3.432609e+04    6.494507
# min      12.000000       5.000000  4.000000e+01    1.000000
# 25%    1722.000000     240.000000  8.700000e+02    2.000000
# 50%    3569.000000     390.000000  1.300000e+03    3.000000
# 75%    5607.000000    1000.000000  2.700000e+03    6.000000
# max    7443.000000  300000.000000  1.200000e+06   90.000000

# %%
itemDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4565 entries, 0 to 4564
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   num_id         4565 non-null   int64
#  1   id             4565 non-null   object
#  2   name           4565 non-null   object
#  3   category       4565 non-null   object
#  4   orderable      1790 non-null   object
#  5   sell_value     4529 non-null   float64
#  6   sell_currency  4529 non-null   object
#  7   buy_value      3551 non-null   float64
#  8   buy_currency   3551 non-null   object
#  9   sources        902 non-null    object
#  10  customizable   573 non-null    object
#  11  recipe         588 non-null    float64
#  12  recipe_id      588 non-null    object
#  13  games_id       4565 non-null   object
#  14  id_full        3037 non-null   object
#  15  image_url      3037 non-null   object
# dtypes: float64(3), int64(1), object(12)
# memory usage: 570.8+ KB

# %%
villagerDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   row_n        391 non-null    int64
#  1   id           390 non-null    object
#  2   name         391 non-null    object
#  3   gender       391 non-null    object
#  4   species      391 non-null    object
#  5   birthday     391 non-null    object
#  6   personality  391 non-null    object
#  7   song         380 non-null    object
#  8   phrase       391 non-null    object
#  9   full_id      391 non-null    object
#  10  url          391 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 33.7+ KB
